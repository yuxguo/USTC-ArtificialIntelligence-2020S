# %%
import pandas as pd
import numpy as np
import os
from sklearn import preprocessing

# %%
train = pd.read_csv('../data/student-mat.csv', sep=';')

# %%
le = preprocessing.LabelEncoder()

# %%
for c in train.columns:
    fields = list(set(train[c]))
    if not (isinstance(fields[0], str) or isinstance(fields[0], bool)):
    # need not to convert
        continue
    le = preprocessing.LabelEncoder()
    le.fit(fields)
    print(le.classes_)
    train[c] = le.transform(train[c])
# Out:
# ['GP' 'MS']
# ['F' 'M']
# ['R' 'U']
# ['GT3' 'LE3']
# ['A' 'T']
# ['at_home' 'health' 'other' 'services' 'teacher']
# ['at_home' 'health' 'other' 'services' 'teacher']
# ['course' 'home' 'other' 'reputation']
# ['father' 'mother' 'other']
# ['no' 'yes']
# ['no' 'yes']
# ['no' 'yes']
# ['no' 'yes']
# ['no' 'yes']
# ['no' 'yes']
# ['no' 'yes']
# ['no' 'yes']
# [False  True]

# %%
train
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0         0    0   18        1        0        0     4     4     0     4  ...
# 1         0    0   17        1        0        1     1     1     0     2  ...
# 2         0    0   15        1        1        1     1     1     0     2  ...
# 3         0    0   15        1        0        1     4     2     1     3  ...
# 4         0    0   16        1        0        1     3     3     2     2  ...
# ..      ...  ...  ...      ...      ...      ...   ...   ...   ...   ...  ...
# 390       1    1   20        1        1        0     2     2     3     3  ...
# 391       1    1   17        1        1        1     3     1     3     3  ...
# 392       1    1   21        0        0        1     1     1     2     2  ...
# 393       1    1   18        0        1        1     3     2     3     2  ...
# 394       1    1   19        1        1        1     1     1     2     0  ...
#
#      famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 0         4         3      4     1     1       3         6   5   6   0
# 1         5         3      3     1     1       3         4   5   5   0
# 2         4         3      2     2     3       3        10   7   8   0
# 3         3         2      2     1     1       5         2  15  14   1
# 4         4         3      2     1     2       5         4   6  10   0
# ..      ...       ...    ...   ...   ...     ...       ...  ..  ..  ..
# 390       5         5      4     4     5       4        11   9   9   0
# 391       2         4      5     3     4       2         3  14  16   1
# 392       5         5      3     3     3       3         3  10   8   0
# 393       4         4      1     3     4       5         0  11  12   0
# 394       3         2      3     3     3       5         5   8   9   0
#
# [395 rows x 33 columns]

# %%
print(isinstance(False,str))
# Out:
# False

# %%
def data_loader(dataset_dir, rnd=False, ratio=0.7, select_col=None, dst_col='G3'):
    data = pd.read_csv(dataset_dir, sep=';')
    data[dst_col] = data[dst_col] >= 10
    # use LabelEncoder
    for c in data.columns:
        fields = list(set(data[c]))
        if not (isinstance(fields[0], str) or isinstance(fields[0], bool)):
            # need not to convert
            continue
        le = preprocessing.LabelEncoder()
        le.fit(fields)
        data[c] = le.transform(data[c])

    if select_col is not None:
        data_x = data[data.columns.difference([dst_col])][select_col].copy()
    else:
        data_x = data[data.columns.difference([dst_col])].copy()
    data_y = data[dst_col].copy()
    idx = np.arange(len(data))
    if rnd:
        np.random.shuffle(idx)
    idx_train = idx[:int(ratio * len(idx))]
    idx_test = idx[int(ratio * len(idx)):]

    train_x = np.array(data_x).copy()[idx_train]
    train_y = np.array(data_y).copy()[idx_train]
    test_x = np.array(data_x).copy()[idx_test]
    test_y = np.array(data_y).copy()[idx_test]

    return train_x, train_y, test_x, test_y

# %%
train_x, train_y, test_x, test_y = data_loader('../data/student-mat.csv')

# %%
train_x.shape
# Out:
# (276, 32)

# %%
a = np.array([[1], [1], [1], [0], [0], [0]])

# %%
b = np.array([[1], [0],[1], [0],[1], [0],])

# %%
a.shape
# Out:
# (6, 1)

# %%
b.shape
# Out:
# (6, 1)

# %%
n
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-07e036783213> in <module>
# ----> 1 a == 1 and b == 1
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
